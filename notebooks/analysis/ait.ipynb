# %% [markdown]
# # Analyze AIT Log v2 Attack Phases

# %%
import pandas as pd

from utils import analyze_phase, analyze_origin_destination

# %% [markdown]
# ## Load MSA Data

# %%
dataset = "aitv2"
scenario = "santos"
data_dir = f"../../data/interim/{dataset}/{scenario}/flows_labeled"
file_path = f"{data_dir}/all_flows_behavioral.csv"

# %%
df = pd.read_csv(file_path)

# %%
print("Phase distribution:")
df.value_counts("phase")
# Out:
# Phase distribution:
# phase
# 0    333964
# 1     12861
# 2      5670
# 4       228
# 3        26
# Name: count, dtype: int64

# %% [markdown]
# ## Feature Analysis

# %%
categorical_cols = [
    "sport",
    "dport",
    "proto",
    "service",
    "conn_state", 
    "local_orig",
    "local_resp",
    "history",    
    "tunnel_parents",
    "ip_proto",   
]

# %%
# check potential issues with categorical features
for col in categorical_cols:
    df_col = df[col]
    df_col_count = df_col.value_counts()
    print(f"Unique values in {col}: {len(df_col_count)}")
# Out:
# Unique values in sport: 47841
# Unique values in dport: 1084
# Unique values in proto: 4
# Unique values in service: 15
# Unique values in conn_state: 12
# Unique values in local_orig: 1
# Unique values in local_resp: 2
# Unique values in history: 1254
# Unique values in tunnel_parents: 1
# Unique values in ip_proto: 5

# %%
conn_state_counts = df["conn_state"].value_counts()
print("Connection state distribution:")
print(conn_state_counts)
# Out:
# Connection state distribution:
# conn_state
# SF       214205
# RSTO      50075
# S0        48814
# OTH       18989
# RSTR      10359
# REJ        6794
# S3         3237
# SH          125
# SHR          93
# S1           22
# RSTRH        21
# S2           15
# Name: count, dtype: int64

# %% [markdown]
# ## Per Phase Analysis

# %%
df_benign = df[df["phase"] == 0]
df_phase_1 = df[df["phase"] == 1]
df_phase_2 = df[df["phase"] == 2]
df_phase_3 = df[df["phase"] == 3]
df_phase_4 = df[df["phase"] == 4]

# %% [markdown]
# ### Behavioral Features Analysis

# %%
behavioral_features = [
    "connections_per_src_60s",
    "unique_targets_60s",
    "unique_dports_60s",
    "syn_failure_ratio_60s",
    "reject_ratio_60s",
    "reset_ratio_60s",
    "connections_per_dst_60s",
    "unique_sources_per_dst_60s",
]

# %%
df_1_augmented_stats = df_phase_1[behavioral_features].describe()
print("\nPhase 1 Statistics:")
print(df_1_augmented_stats)
# Out:
# Phase 1 Statistics:
#        connections_per_src_60s  unique_targets_60s  unique_dports_60s  \
# count             12861.000000             12861.0            12861.0
# mean                  4.259000                 1.0                1.0
# std                   0.454139                 0.0                0.0
# min                   1.000000                 1.0                1.0
# 25%                   4.000000                 1.0                1.0
# 50%                   4.000000                 1.0                1.0
# 75%                   5.000000                 1.0                1.0
# max                   7.000000                 1.0                1.0
#
#        syn_failure_ratio_60s  reject_ratio_60s  reset_ratio_60s  \
# count           12861.000000           12861.0          12861.0
# mean                0.497539               0.0              0.0
# std                 0.247804               0.0              0.0
# min                 0.000000               0.0              0.0
# 25%                 0.250000               0.0              0.0
# 50%                 0.500000               0.0              0.0
# 75%                 0.750000               0.0              0.0
# max                 1.000000               0.0              0.0
#
#        connections_per_dst_60s  unique_sources_per_dst_60s
# count             12861.000000                     12861.0
# mean                  4.259000                         1.0
# std                   0.454139                         0.0
# min                   1.000000                         1.0
# 25%                   4.000000                         1.0
# 50%                   4.000000                         1.0
# 75%                   5.000000                         1.0
# max                   7.000000                         1.0

# %%
df_2_augmented_stats = df_phase_2[behavioral_features].describe()
print("\nPhase 2 Statistics:")
print(df_2_augmented_stats)
# Out:
# Phase 2 Statistics:
#        connections_per_src_60s  unique_targets_60s  unique_dports_60s  \
# count              5670.000000         5670.000000        5670.000000
# mean               2287.094180          203.681834         374.915344
# std                1540.889517          105.055718         143.359730
# min                   1.000000            1.000000           1.000000
# 25%                 793.250000          251.000000         311.000000
# 50%                2239.500000          262.000000         357.000000
# 75%                3633.750000          262.000000         491.000000
# max                5011.000000          262.000000         593.000000
#
#        syn_failure_ratio_60s  reject_ratio_60s  reset_ratio_60s  \
# count            5670.000000       5670.000000      5670.000000
# mean                0.296193          0.562184         0.044247
# std                 0.190495          0.224606         0.106841
# min                 0.000000          0.000000         0.000000
# 25%                 0.225540          0.394705         0.018592
# 50%                 0.286037          0.590178         0.024386
# 75%                 0.427755          0.692662         0.034623
# max                 0.668253          1.000000         1.000000
#
#        connections_per_dst_60s  unique_sources_per_dst_60s
# count              5670.000000                 5670.000000
# mean                546.028748                    2.387302
# std                 476.407754                    0.692358
# min                   2.000000                    2.000000
# 25%                  97.250000                    2.000000
# 50%                 445.000000                    2.000000
# 75%                 906.750000                    3.000000
# max                1643.000000                    7.000000

# %%
df_3_augmented_stats = df_phase_3[behavioral_features].describe()
print("\nPhase 3 Statistics:")
print(df_3_augmented_stats)
# Out:
# Phase 3 Statistics:
#        connections_per_src_60s  unique_targets_60s  unique_dports_60s  \
# count                26.000000                26.0               26.0
# mean                 76.653846                 3.0                2.0
# std                  46.302434                 0.0                0.0
# min                  42.000000                 3.0                2.0
# 25%                  50.000000                 3.0                2.0
# 50%                  52.000000                 3.0                2.0
# 75%                  92.750000                 3.0                2.0
# max                 179.000000                 3.0                2.0
#
#        syn_failure_ratio_60s  reject_ratio_60s  reset_ratio_60s  \
# count                   26.0              26.0        26.000000
# mean                     0.0               0.0         0.299577
# std                      0.0               0.0         0.375838
# min                      0.0               0.0         0.000000
# 25%                      0.0               0.0         0.000000
# 50%                      0.0               0.0         0.000000
# 75%                      0.0               0.0         0.672101
# max                      0.0               0.0         0.932584
#
#        connections_per_dst_60s  unique_sources_per_dst_60s
# count                26.000000                        26.0
# mean                110.115385                         2.0
# std                  71.039328                         0.0
# min                  59.000000                         2.0
# 25%                  68.000000                         2.0
# 50%                  72.000000                         2.0
# 75%                 136.750000                         2.0
# max                 266.000000                         2.0

# %%
df_4_augmented_stats = df_phase_4[behavioral_features].describe()
print("\nPhase 4 Statistics:")
print(df_4_augmented_stats)
# Out:
# Phase 4 Statistics:
#        connections_per_src_60s  unique_targets_60s  unique_dports_60s  \
# count                228.00000          228.000000         228.000000
# mean                  20.04386            2.622807           1.982456
# std                   13.33036            1.934570           1.082357
# min                    1.00000            1.000000           1.000000
# 25%                    7.00000            1.000000           1.000000
# 50%                   20.00000            2.000000           2.000000
# 75%                   33.00000            3.000000           3.000000
# max                   53.00000           12.000000           5.000000
#
#        syn_failure_ratio_60s  reject_ratio_60s  reset_ratio_60s  \
# count             228.000000             228.0       228.000000
# mean                0.008884               0.0         0.285908
# std                 0.093457               0.0         0.329142
# min                 0.000000               0.0         0.000000
# 25%                 0.000000               0.0         0.000000
# 50%                 0.000000               0.0         0.081250
# 75%                 0.000000               0.0         0.575630
# max                 1.000000               0.0         0.965517
#
#        connections_per_dst_60s  unique_sources_per_dst_60s
# count               228.000000                  228.000000
# mean                 26.135965                    4.425439
# std                  16.469273                    1.970859
# min                   1.000000                    1.000000
# 25%                  12.750000                    3.000000
# 50%                  22.500000                    5.000000
# 75%                  39.000000                    6.000000
# max                  72.000000                    8.000000

# %% [markdown]
# ### Phase 1 - Data Exfiltration

# %%
phase_1_labels = df_phase_1["label"].value_counts()
print("Phase 1 Label Distribution:")
print(phase_1_labels)
# Out:
# Phase 1 Label Distribution:
# label
# data exfiltration    12861
# Name: count, dtype: int64

# %%
analyze_phase(df_phase_1, "Phase 1")
# Out:
# Total Flows: 12861
#
#  --- IP distribution ---
#
# Source IPs (1):
# src_ip
# 10.229.255.254    12861
# Name: count, dtype: int64
#
# Destination IPs (1):
# dst_ip
# 10.229.2.216    12861
# Name: count, dtype: int64
#
#  --- Port distribution ---
# Source Ports (11598):
# sport
# 1772     4
# 8931     4
# 6966     4
# 60954    3
# 62882    3
#         ..
# 58934    1
# 18514    1
# 48402    1
# 25045    1
# 23702    1
# Name: count, Length: 11598, dtype: int64
#
# Destination Ports (1):
# dport
# 53    12861
# Name: count, dtype: int64
#
#  --- Protocol distribution ---
# proto
# udp    12861
# Name: count, dtype: int64
#
#  --- Service distribution ---
# service
# dns    12861
# Name: count, dtype: int64
# (src_ip
#  10.229.255.254    12861
#  Name: count, dtype: int64,
#  dst_ip
#  10.229.2.216    12861
#  Name: count, dtype: int64,
#  sport
#  1772     4
#  8931     4
#  6966     4
#  60954    3
#  62882    3
#          ..
#  58934    1
#  18514    1
#  48402    1
#  25045    1
#  23702    1
#  Name: count, Length: 11598, dtype: int64,
#  dport
#  53    12861
#  Name: count, dtype: int64)

# %%
analyze_origin_destination(df_phase_1, "Phase 1")
# Out:
# Phase 1 Origin Distribution:
# local_orig
# T    12861
# Name: count, dtype: int64
# Phase 1 Destination Distribution:
# local_resp
# T    12861
# Name: count, dtype: int64

# %% [markdown]
# ### Phase 2 - Scanning

# %%
print("Number of samples in Phase 2:", len(df_phase_2))
# Out:
# Number of samples in Phase 2: 5670

# %%
analyze_origin_destination(df_phase_2, "Phase 2")
# Out:
# Phase 2 Origin Distribution:
# local_orig
# T    5670
# Name: count, dtype: int64
# Phase 2 Destination Distribution:
# local_resp
# T    5670
# Name: count, dtype: int64

# %%
analyze_phase(df_phase_2, "Phase 2")
# Out:
# Total Flows: 5670
#
#  --- IP distribution ---
#
# Source IPs (2):
# src_ip
# 172.21.128.119    5074
# 10.229.2.216       596
# Name: count, dtype: int64
#
# Destination IPs (263):
# dst_ip
# 192.168.104.155    1035
# 172.21.131.50       896
# 172.21.128.54       870
# 192.168.104.218     841
# 10.229.255.254      596
#                    ...
# 192.168.104.95        1
# 192.168.104.198       1
# 192.168.104.141       1
# 192.168.104.81        1
# 192.168.104.98        1
# Name: count, Length: 263, dtype: int64
#
#  --- Port distribution ---
# Source Ports (3807):
# sport
# 41554    6
# 60056    6
# 49810    5
# 56148    5
# 44526    5
#         ..
# 47190    1
# 54112    1
# 53852    1
# 41092    1
# 34884    1
# Name: count, Length: 3807, dtype: int64
#
# Destination Ports (592):
# dport
# 443     834
# 80      589
# 587      26
# 993      14
# 139      14
#        ...
# 146       5
# 8873      5
# 5633      5
# 800       5
# 1088      5
# Name: count, Length: 592, dtype: int64
#
#  --- Protocol distribution ---
# proto
# tcp    5670
# Name: count, dtype: int64
#
#  --- Service distribution ---
# service
# -       5301
# ssl      326
# http      40
# imap       2
# dns        1
# Name: count, dtype: int64
# (src_ip
#  172.21.128.119    5074
#  10.229.2.216       596
#  Name: count, dtype: int64,
#  dst_ip
#  192.168.104.155    1035
#  172.21.131.50       896
#  172.21.128.54       870
#  192.168.104.218     841
#  10.229.255.254      596
#                     ...
#  192.168.104.95        1
#  192.168.104.198       1
#  192.168.104.141       1
#  192.168.104.81        1
#  192.168.104.98        1
#  Name: count, Length: 263, dtype: int64,
#  sport
#  41554    6
#  60056    6
#  49810    5
#  56148    5
#  44526    5
#          ..
#  47190    1
#  54112    1
#  53852    1
#  41092    1
#  34884    1
#  Name: count, Length: 3807, dtype: int64,
#  dport
#  443     834
#  80      589
#  587      26
#  993      14
#  139      14
#         ...
#  146       5
#  8873      5
#  5633      5
#  800       5
#  1088      5
#  Name: count, Length: 592, dtype: int64)

# %%
df_phase_2.label.value_counts()
# Out:
# label
# service_scan             4056
# host_discover_local      1000
# dns_brute_force_start     325
# host_discover_dmz         115
# dirb_scan                  90
# wpscan                     84
# Name: count, dtype: int64

# %%
phase_2_labels = df_phase_2["label"].unique()
print("Unique labels in Phase 2:", phase_2_labels)
# Out:
# Unique labels in Phase 2: ['host_discover_dmz' 'dns_brute_force_start' 'host_discover_local'
#  'service_scan' 'dirb_scan' 'wpscan']

# %%
phase_2_brute_force = df_phase_2[df_phase_2["label"] == "dns_brute_force_start"]
analyze_phase(phase_2_brute_force, "Phase 2 - DNS Brute Force")
# Out:
# Total Flows: 325
#
#  --- IP distribution ---
#
# Source IPs (1):
# src_ip
# 172.21.128.119    325
# Name: count, dtype: int64
#
# Destination IPs (2):
# dst_ip
# 172.21.128.1      313
# 172.21.129.224     12
# Name: count, dtype: int64
#
#  --- Port distribution ---
# Source Ports (319):
# sport
# 35614    2
# 35616    2
# 35618    2
# 35620    2
# 35622    2
#         ..
# 47496    1
# 54770    1
# 42262    1
# 43602    1
# 50070    1
# Name: count, Length: 319, dtype: int64
#
# Destination Ports (311):
# dport
# 443      14
# 80        2
# 514       1
# 37        1
# 1027      1
#          ..
# 8081      1
# 7100      1
# 888       1
# 10243     1
# 1039      1
# Name: count, Length: 311, dtype: int64
#
#  --- Protocol distribution ---
# proto
# tcp    325
# Name: count, dtype: int64
#
#  --- Service distribution ---
# service
# -      313
# ssl     12
# Name: count, dtype: int64
# (src_ip
#  172.21.128.119    325
#  Name: count, dtype: int64,
#  dst_ip
#  172.21.128.1      313
#  172.21.129.224     12
#  Name: count, dtype: int64,
#  sport
#  35614    2
#  35616    2
#  35618    2
#  35620    2
#  35622    2
#          ..
#  47496    1
#  54770    1
#  42262    1
#  43602    1
#  50070    1
#  Name: count, Length: 319, dtype: int64,
#  dport
#  443      14
#  80        2
#  514       1
#  37        1
#  1027      1
#           ..
#  8081      1
#  7100      1
#  888       1
#  10243     1
#  1039      1
#  Name: count, Length: 311, dtype: int64)

# %% [markdown]
# ### Phase 3 - Exploitation

# %%
df_phase_3.head(10)
# Out:
#        flow_id    start_time      end_time  duration          src_ip  sport  \
# 311919  f24386  1.642419e+09  1.642419e+09  3.172493  172.21.128.119  44674
# 311920  f12338  1.642419e+09  1.642419e+09  3.171754  172.21.128.119  44674
# 311927  f24388  1.642419e+09  1.642419e+09  0.095648  172.21.128.119  44678
# 311928  f12340  1.642419e+09  1.642419e+09  0.094994  172.21.128.119  44678
# 311982  f24392  1.642419e+09  1.642419e+09  0.093564  172.21.128.119  44686
# 311983  f12344  1.642419e+09  1.642419e+09  0.092939  172.21.128.119  44686
# 312016  f24400  1.642419e+09  1.642419e+09  0.150203  172.21.128.119  44698
# 312017  f12351  1.642419e+09  1.642419e+09  0.149455  172.21.128.119  44698
# 312028  f24403  1.642419e+09  1.642419e+09  0.098250  172.21.128.119  44704
# 312029  f12354  1.642419e+09  1.642419e+09  0.097714  172.21.128.119  44704
#
#                  dst_ip  dport proto service  ...  \
# 311919  192.168.104.155    443   tcp     ssl  ...
# 311920  192.168.104.155    443   tcp     ssl  ...
# 311927  192.168.104.155    443   tcp     ssl  ...
# 311928  192.168.104.155    443   tcp     ssl  ...
# 311982  192.168.104.155    443   tcp     ssl  ...
# 311983  192.168.104.155    443   tcp     ssl  ...
# 312016  192.168.104.155    443   tcp     ssl  ...
# 312017  192.168.104.155    443   tcp     ssl  ...
# 312028  192.168.104.155    443   tcp     ssl  ...
# 312029  192.168.104.155    443   tcp     ssl  ...
#
#                           end_time_dt  phase connections_per_src_60s  \
# 311919  2022-01-17 11:23:00.334796906      3                     178
# 311920  2022-01-17 11:23:00.334776878      3                     179
# 311927  2022-01-17 11:23:03.605890036      3                     172
# 311928  2022-01-17 11:23:03.605802059      3                     173
# 311982  2022-01-17 11:23:16.605823994      3                     100
# 311983  2022-01-17 11:23:16.605835915      3                     101
# 312016  2022-01-17 11:23:31.503515959      3                      92
# 312017  2022-01-17 11:23:31.503534079      3                      93
# 312028  2022-01-17 11:23:39.960888863      3                      58
# 312029  2022-01-17 11:23:39.960873842      3                      59
#
#        unique_targets_60s unique_dports_60s  syn_failure_ratio_60s  \
# 311919                  3                 2                    0.0
# 311920                  3                 2                    0.0
# 311927                  3                 2                    0.0
# 311928                  3                 2                    0.0
# 311982                  3                 2                    0.0
# 311983                  3                 2                    0.0
# 312016                  3                 2                    0.0
# 312017                  3                 2                    0.0
# 312028                  3                 2                    0.0
# 312029                  3                 2                    0.0
#
#        reject_ratio_60s  reset_ratio_60s  connections_per_dst_60s  \
# 311919              0.0         0.932584                      265
# 311920              0.0         0.927374                      266
# 311927              0.0         0.906977                      256
# 311928              0.0         0.901734                      257
# 311982              0.0         0.780000                      148
# 311983              0.0         0.772277                      149
# 312016              0.0         0.673913                      136
# 312017              0.0         0.666667                      137
# 312028              0.0         0.379310                       84
# 312029              0.0         0.372881                       85
#
#         unique_sources_per_dst_60s
# 311919                           2
# 311920                           2
# 311927                           2
# 311928                           2
# 311982                           2
# 311983                           2
# 312016                           2
# 312017                           2
# 312028                           2
# 312029                           2
#
# [10 rows x 36 columns]

# %%
df_phase_3_services = df_phase_3["service"].value_counts()
print("Phase 3 Service Distribution:")
print(df_phase_3_services)
# Out:
# Phase 3 Service Distribution:
# service
# ssl    26
# Name: count, dtype: int64

# %%
phase_3_labels = df_phase_3["label"].unique()
print("Unique labels in Phase 3:", phase_3_labels)
# Out:
# Unique labels in Phase 3: ['upload_rce_shell' 'check_user_id' 'check_date' 'check_network_config'
#  'check_ps_a' 'read_resolv' 'read_passwd' 'check_release'
#  'check_netstat_t' 'list_web_dir' 'read_group' 'check_wp_config'
#  'dump_wp_users']

# %%
analyze_origin_destination(df_phase_3, "Phase 3")
# Out:
# Phase 3 Origin Distribution:
# local_orig
# T    26
# Name: count, dtype: int64
# Phase 3 Destination Distribution:
# local_resp
# T    26
# Name: count, dtype: int64

# %%
analyze_phase(df_phase_3, "Phase 3")
# Out:
# Total Flows: 26
#
#  --- IP distribution ---
#
# Source IPs (1):
# src_ip
# 172.21.128.119    26
# Name: count, dtype: int64
#
# Destination IPs (1):
# dst_ip
# 192.168.104.155    26
# Name: count, dtype: int64
#
#  --- Port distribution ---
# Source Ports (13):
# sport
# 44674    2
# 44678    2
# 44686    2
# 44698    2
# 44704    2
# 44706    2
# 44712    2
# 44714    2
# 44716    2
# 44720    2
# 44726    2
# 44728    2
# 44730    2
# Name: count, dtype: int64
#
# Destination Ports (1):
# dport
# 443    26
# Name: count, dtype: int64
#
#  --- Protocol distribution ---
# proto
# tcp    26
# Name: count, dtype: int64
#
#  --- Service distribution ---
# service
# ssl    26
# Name: count, dtype: int64
# (src_ip
#  172.21.128.119    26
#  Name: count, dtype: int64,
#  dst_ip
#  192.168.104.155    26
#  Name: count, dtype: int64,
#  sport
#  44674    2
#  44678    2
#  44686    2
#  44698    2
#  44704    2
#  44706    2
#  44712    2
#  44714    2
#  44716    2
#  44720    2
#  44726    2
#  44728    2
#  44730    2
#  Name: count, dtype: int64,
#  dport
#  443    26
#  Name: count, dtype: int64)

# %%
analyze_origin_destination(df_phase_3, "Phase 3")
# Out:
# Phase 3 Origin Distribution:
# local_orig
# T    26
# Name: count, dtype: int64
# Phase 3 Destination Distribution:
# local_resp
# T    26
# Name: count, dtype: int64

# %% [markdown]
# ### Phase 4 - Password Cracking

# %%
analyze_phase(df_phase_4, "Phase 4")
# Out:
# Total Flows: 228
#
#  --- IP distribution ---
#
# Source IPs (4):
# src_ip
# 172.21.128.119     222
# 10.229.0.4           3
# 10.229.1.118         2
# 192.168.104.155      1
# Name: count, dtype: int64
#
# Destination IPs (4):
# dst_ip
# 172.21.129.224     182
# 192.168.104.155     40
# 10.229.2.216         3
# 10.229.2.25          3
# Name: count, dtype: int64
#
#  --- Port distribution ---
# Source Ports (114):
# sport
# 44636    3
# 44732    2
# 44734    2
# 48904    2
# 44736    2
#         ..
# 35800    2
# 48992    2
# 48990    2
# 48994    2
# 51280    1
# Name: count, Length: 114, dtype: int64
#
# Destination Ports (3):
# dport
# 443    208
# 80      19
# 25       1
# Name: count, dtype: int64
#
#  --- Protocol distribution ---
# proto
# tcp    228
# Name: count, dtype: int64
#
#  --- Service distribution ---
# service
# ssl     208
# http     19
# smtp      1
# Name: count, dtype: int64
# (src_ip
#  172.21.128.119     222
#  10.229.0.4           3
#  10.229.1.118         2
#  192.168.104.155      1
#  Name: count, dtype: int64,
#  dst_ip
#  172.21.129.224     182
#  192.168.104.155     40
#  10.229.2.216         3
#  10.229.2.25          3
#  Name: count, dtype: int64,
#  sport
#  44636    3
#  44732    2
#  44734    2
#  48904    2
#  44736    2
#          ..
#  35800    2
#  48992    2
#  48990    2
#  48994    2
#  51280    1
#  Name: count, Length: 114, dtype: int64,
#  dport
#  443    208
#  80      19
#  25       1
#  Name: count, dtype: int64)

# %%
df_phase_4_protocols = df_phase_4["dport"].value_counts()
print("Phase 4 Service Distribution:")
print(df_phase_4_protocols)
# Out:
# Phase 4 Service Distribution:
# dport
# 443    208
# 80      19
# 25       1
# Name: count, dtype: int64

# %% [markdown]
# ### Phase 0 - Benign Activity

# %%
analyze_origin_destination(df_benign, "Benign")
# Out:
# Benign Origin Distribution:
# local_orig
# T    333964
# Name: count, dtype: int64
# Benign Destination Distribution:
# local_resp
# T    273029
# F     60935
# Name: count, dtype: int64

# %%
analyze_origin_destination(df, "All")
# Out:
# All Origin Distribution:
# local_orig
# T    352749
# Name: count, dtype: int64
# All Destination Distribution:
# local_resp
# T    291814
# F     60935
# Name: count, dtype: int64
