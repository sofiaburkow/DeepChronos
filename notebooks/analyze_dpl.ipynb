# %% [markdown]
# # Analyze DARPA Flags Results

# %%
from pathlib import Path
import json
import pickle
from itertools import product

import numpy as np
import pandas as pd

# %%
from analyze import (
    is_hard_violation,
    is_soft_violation,
    mis_metrics,
    plot_mis_predictions
)

# %%
# run_id = "20260313_080703"
run_id = "20260315_111546"
logic_file = "darpa_flags_ports_ips"

# %% [markdown]
# ## Load Original Flows

# %%
# Dataset configuration
dataset = "darpa2000"
scenario = "s1_inside"

# %%
df = pd.read_csv(
    f"../data/interim/{dataset}/{scenario}/flows_labeled/all_flows_labeled.csv"
)

df = df.sort_values("start_time").reset_index(drop=True)
df['t_rel'] = df['start_time'] - df['start_time'].min()

# %%
phase_bounds = (
    df[df['phase'] > 0]
    .groupby('phase')['t_rel']
    .agg(['min', 'max'])
)

phase_start = phase_bounds['min'].to_dict()
phase_end   = phase_bounds['max'].to_dict()

# %%
phase_bounds
# Out:
#                min          max
# phase
# 1      1799.665435  1824.341042
# 2      2790.877254  3333.974143
# 3      4294.134775  4402.837414
# 4      5305.272464  5357.444592
# 5      7478.960660  8383.254878

# %% [markdown]
# ## Load DPL Dataset

# %%
# logic_file = [
#     "darpa_flags",
# ]

# dataset_variant = [
#     "original", 
#     # "resampled",
# ]

# window_sizes = [
#     10, 
#     # 50, 
#     # 100,
# ]

# %%
# Experiment configuration
train_mode = "scratch"
dataset_variant = "resampled"
window_size = 10

# %%
dpl_dataset_dir = Path(f"../experiments/{dataset}/{scenario}/deepproblog/{logic_file}/cache/")
cache_file_test = dpl_dataset_dir / f"{logic_file}_{dataset_variant}_w{window_size}_test.pkl"

# %%
# Load DPL dataset
cache = pickle.load(open(cache_file_test, "rb"))
cache_df = pd.DataFrame(cache)
cache_df.head()
# Out:
#    dpl_index  orig_index    start_time          src_ip         dst_ip  sport  \
# 0          0          11  9.524389e+08  172.16.112.100  172.16.115.20   1064
# 1          1          14  9.524389e+08  172.16.112.100  172.16.115.20   1066
# 2          2          18  9.524389e+08  172.16.112.100  172.16.115.20   1070
# 3          3          19  9.524389e+08  172.16.112.100  172.16.115.20   1071
# 4          4          21  9.524389e+08  172.16.112.100  172.16.115.20   1073
#
#    dport  phase                     flags phase_counts   label
# 0     53      0  {1: 0, 2: 0, 3: 0, 4: 0}           {}  benign
# 1     53      0  {1: 0, 2: 0, 3: 0, 4: 0}       {0: 1}  benign
# 2     53      0  {1: 0, 2: 0, 3: 0, 4: 0}       {0: 2}  benign
# 3     53      0  {1: 0, 2: 0, 3: 0, 4: 0}       {0: 3}  benign
# 4     53      0  {1: 0, 2: 0, 3: 0, 4: 0}       {0: 4}  benign

# %% [markdown]
# ## Analyze Results

# %%
results = []

# %%
# for logic, dataset_variant, window_size in product(
#     logic_file,
#     dataset_variant,
#     window_sizes,
# ):
    
errors_dir = f"../experiments/{dataset}/{scenario}/deepproblog/{logic_file}/errors"
experiment_name = f"{logic_file}_{train_mode}_{dataset_variant}_w{window_size}"
# run_id = "20260311_153748"
# run_id = "20260311_160847"
# run_id = "20260312_163325"
# run_id = "20260312_171549"
# run_id = "20260312_173806"

errors_file = (
    f"{errors_dir}/"
    f"{experiment_name}_{run_id}.json"
)
    
with open(errors_file) as f:
    errors = json.load(f)

# %%
# Build lookup once
dpl_to_orig = dict(zip(cache_df['dpl_index'], cache_df['orig_index']))

original_indices = []
mis_y_preds = []
mis_y_trues = []

phase_map = {
    "benign": 0,
    "phase1": 1,
    "phase2": 2,
    "phase3": 3,
    "phase4": 4,
    "phase5": 5,
}

for error in errors:
    dpl_index = error['index']

    original_indices.append(dpl_to_orig[dpl_index])
    y_pred = error['predicted']
    y_true = error['actual']
    mis_y_preds.append(phase_map[y_pred])
    mis_y_trues.append(phase_map[y_true])

mis_df = df.loc[original_indices].copy()
mis_df['y_pred'] = mis_y_preds
mis_df['y_true'] = mis_y_trues

# %%
mis_df.head(10)
# Out:
#       flow_id    start_time      end_time  duration          src_ip  sport  \
# 17567  f17534  9.524401e+08  9.524401e+08  0.011254  135.13.216.191  44361
# 20733  f20714  9.524405e+08  9.524405e+08  0.010538  135.13.216.191  44707
# 20734  f20715  9.524405e+08  9.524405e+08  0.011901  135.13.216.191  44708
# 21691  f21653  9.524407e+08  9.524407e+08  0.001020  172.16.113.168   1884
# 22168  f22283  9.524409e+08  9.524409e+08  0.000000   172.16.116.20    138
# 22957  f23094  9.524412e+08  9.524412e+08  0.000000   172.16.116.15    138
# 23132  f23109  9.524412e+08  9.524412e+08  0.368872  197.182.91.233  45517
# 23250  f23446  9.524413e+08  9.524413e+08  0.064471  135.13.216.191      8
# 23252  f23453  9.524413e+08  9.524413e+08  0.000000    172.16.112.1    123
# 23264  f23244  9.524413e+08  9.524413e+08  0.259865  135.13.216.191  45555
#
#                dst_ip  dport proto service  ...  orig_pkts  orig_ip_bytes  \
# 17567  172.16.112.100     80   tcp    http  ...          5            533
# 20733  172.16.112.100     80   tcp    http  ...          5            537
# 20734  172.16.112.100     80   tcp    http  ...          5            535
# 21691   172.16.115.20     53   udp     dns  ...          1             61
# 22168  172.16.255.255    138   udp       -  ...          1            233
# 22957  172.16.116.255    138   udp       -  ...          1            243
# 23132  172.16.113.169     25   tcp    smtp  ...         12           1540
# 23250  172.16.113.169      0  icmp       -  ...          9            342
# 23252  172.16.112.255    123   udp     ntp  ...          1             76
# 23264  172.16.113.169     25   tcp    smtp  ...         15           4800
#
#       resp_pkts resp_ip_bytes tunnel_parents  ip_proto phase        t_rel  \
# 17567         4          1266              -         6     0  1189.171837
# 20733         5          2929              -         6     0  1561.803985
# 20734         5          2738              -         6     0  1561.825524
# 21691         1           119              -        17     0  1827.382121
# 22168         0             0              -        17     0  1974.631106
# 22957         0             0              -        17     0  2253.763033
# 23132        12           820              -         6     0  2318.204524
# 23250         0             0              -         1     0  2405.107653
# 23252         0             0              -        17     0  2412.667483
# 23264        13           858              -         6     0  2427.505035
#
#        y_pred  y_true
# 17567       1       0
# 20733       1       0
# 20734       1       0
# 21691       2       0
# 22168       2       0
# 22957       2       0
# 23132       2       0
# 23250       2       0
# 23252       2       0
# 23264       2       0
#
# [10 rows x 27 columns]

# %%
# --- Compute violation categories ---
wrong, hard, soft, plausible = mis_metrics(mis_df, phase_start)

total_wrong = len(wrong)
hard_rate = len(hard) / total_wrong if total_wrong > 0 else 0
soft_rate = len(soft) / total_wrong if total_wrong > 0 else 0

# --- Collect everything ---
results.append({
    "model": f"{experiment_name}",
    # "accuracy": metrics["accuracy"],
    # "precision" : metrics["precision"],
    # "recall" : metrics["recall"], 
    # "f1": metrics["f1"],
    "total_wrong": total_wrong,
    "hard_violations": len(hard),
    "soft_violations": len(soft),
    "hard_rate": hard_rate,
    "soft_rate": soft_rate,
})

# Create plots
out_dir = Path(f"../reports/{logic_file}")

plot_mis_predictions(
    df, 
    phase_bounds, 
    plausible, 
    soft, 
    hard, 
    total_wrong, 
    soft_rate, 
    hard_rate, 
    experiment_name, 
    out_dir
)

# %%
mis_df
# Out:
#         flow_id    start_time      end_time  duration          src_ip  sport  \
# 17567    f17534  9.524401e+08  9.524401e+08  0.011254  135.13.216.191  44361
# 20733    f20714  9.524405e+08  9.524405e+08  0.010538  135.13.216.191  44707
# 20734    f20715  9.524405e+08  9.524405e+08  0.011901  135.13.216.191  44708
# 21691    f21653  9.524407e+08  9.524407e+08  0.001020  172.16.113.168   1884
# 22168    f22283  9.524409e+08  9.524409e+08  0.000000   172.16.116.20    138
# ...         ...           ...           ...       ...             ...    ...
# 115033  f115007  9.524471e+08  9.524471e+08  0.078300    172.16.115.5  24713
# 115037  f115009  9.524471e+08  9.524471e+08  0.072933    172.16.115.5  24715
# 115298  f115256  9.524473e+08  9.524473e+08  0.031198    172.16.115.5  26715
# 115300  f115257  9.524473e+08  9.524473e+08  0.053366    172.16.115.5  26716
# 115304  f115259  9.524473e+08  9.524473e+08  0.078039    172.16.115.5  26753
#
#                 dst_ip  dport proto service  ...  resp_pkts  resp_ip_bytes  \
# 17567   172.16.112.100     80   tcp    http  ...          4           1266
# 20733   172.16.112.100     80   tcp    http  ...          5           2929
# 20734   172.16.112.100     80   tcp    http  ...          5           2738
# 21691    172.16.115.20     53   udp     dns  ...          1            119
# 22168   172.16.255.255    138   udp       -  ...          0              0
# ...                ...    ...   ...     ...  ...        ...            ...
# 115033     131.84.1.31     80   tcp    http  ...          9           7092
# 115037     131.84.1.31     80   tcp    http  ...         11          13067
# 115298     131.84.1.31     80   tcp    http  ...          4           2432
# 115300     131.84.1.31     80   tcp    http  ...          9           6530
# 115304     131.84.1.31     80   tcp    http  ...         13          15038
#
#        tunnel_parents ip_proto phase        t_rel y_pred  y_true  \
# 17567               -        6     0  1189.171837      1       0
# 20733               -        6     0  1561.803985      1       0
# 20734               -        6     0  1561.825524      1       0
# 21691               -       17     0  1827.382121      2       0
# 22168               -       17     0  1974.631106      2       0
# ...               ...      ...   ...          ...    ...     ...
# 115033              -        6     5  8200.677959      0       5
# 115037              -        6     5  8200.840443      0       5
# 115298              -        6     5  8382.941330      0       5
# 115300              -        6     5  8382.975029      0       5
# 115304              -        6     5  8383.129199      0       5
#
#         hard_violation  soft_violation
# 17567            False           False
# 20733            False           False
# 20734            False           False
# 21691            False           False
# 22168            False           False
# ...                ...             ...
# 115033           False           False
# 115037           False           False
# 115298           False           False
# 115300           False           False
# 115304           False           False
#
# [84 rows x 29 columns]

# %%
def false_positives(df, phase):
    return df[(df["y_true"] != phase) & (df["y_pred"] == phase)]

# %%
def false_negatives(df, phase):
    return df[(df["y_true"] == phase) & (df["y_pred"] != phase)]

# %%
def true_positives(df, phase):
    return df[(df["y_true"] == phase) & (df["y_pred"] == phase)]

# %%
df_fp_2 = false_positives(mis_df, 2)
df_fp_2
# Out:
#       flow_id    start_time      end_time    duration          src_ip  sport  \
# 21691  f21653  9.524407e+08  9.524407e+08    0.001020  172.16.113.168   1884
# 22168  f22283  9.524409e+08  9.524409e+08    0.000000   172.16.116.20    138
# 22957  f23094  9.524412e+08  9.524412e+08    0.000000   172.16.116.15    138
# 23132  f23109  9.524412e+08  9.524412e+08    0.368872  197.182.91.233  45517
# 23250  f23446  9.524413e+08  9.524413e+08    0.064471  135.13.216.191      8
# 23252  f23453  9.524413e+08  9.524413e+08    0.000000    172.16.112.1    123
unnel_parents ip_proto phase        t_rel y_pred  y_true  \
# 21691              -       17     0  1827.382121      2       0
# 22168              -       17     0  1974.631106      2       0
# 22957              -       17     0  2253.763033      2       0
# 23132              -        6     0  2318.204524      2       0
# 23250              -        1     0  2405.107653      2       0
# 23252              -       17     0  2412.667483      2       0
# 23264              -        6     0  2427.505035      2       0
# 23467              -        6     0  2461.809980      2       0
# 23518              -        6     0  2496.202450      2       0
# 23519              -        6     0  2496.228083      2       0
# 23521              -        6     0  2496.258867      2       0
# 23524              -        6     0  2504.665600      2       0
# 23533              -        6     0  2515.792670      2       0
# 23535              -        6     0  2515.824237      2       0
# 23536              -        6     0  2515.839512      2       0
# 23553              -        6     0  2556.225537      2       0
# 23554              -        6     0  2556.240723      2       0
# 23722              -        6     0  2607.402501      2       0
# 23843              -       17     0  2668.672560      2       0
# 23862              -        6     0  2703.913353      2       0
# 23880              -        6     0  2710.782458      2       0
# 23881              -        6     0  2710.824743      2       0
# 23882              -        6     0  2710.852040      2       0
# 23883              -        6     0  2710.866876      2       0
# 23886              -        6     0  2710.913919      2       0
# 23903              -       17     0  2732.668836      2       0
# 24131              -        6     0  2788.554600      2       0
# 24133              -        6     0  2788.587473      2       0
#
#        hard_violation  soft_violation
# 21691           False           False
# 22168           False           False
# 22957           False           False
# 23132           False           False
# 23250           False           False
# 23252           False           False
# 23264           False           False
# 23467           False           False
# 23518           False           False
# 23519           False           False
# 23521           False           False
# 23524           False           False
# 23533           False           False
# 23535           False           False
# 23536           False           False
# 23553           False           False
# 23554           False           False
# 23722           False           False
# 23843           False           False
# 23862           False           False
# 23880           False           False
# 23881           False           False
# 23882           False           False
# 23883           False           False
# 23886           False           False
# 23903           False           False
# 24131           False           False
# 24133           False           False
#
# [28 rows x 29 columns]

# %%
df_fn_2 = false_negatives(mis_df, 2)
df_fn_2
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_tp_2 = true_positives(mis_df, 2)
df_tp_2
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_fp_3 = false_positives(mis_df, 3)
df_fp_3
# Out:
#       flow_id    start_time      end_time  duration          src_ip  sport  \
# 24140  f24197  9.524417e+08  9.524417e+08  0.000000    172.16.113.1    123
# 25738  f25713  9.524421e+08  9.524421e+08  0.000892    192.168.1.50  55795
# 27304  f27277  9.524426e+08  9.524426e+08  0.009911  172.16.113.148     20
# 27661  f27634  9.524428e+08  9.524428e+08  0.016191  172.16.113.148     20
# 29041  f29023  9.524432e+08  9.524432e+08  0.001045  172.16.113.204   1393
#
#                dst_ip  dport proto   service  ...  resp_pkts  resp_ip_bytes  \
# 24140  172.16.113.255    123   udp       ntp  ...          0              0
# 25738   172.16.115.20     53   udp       dns  ...          1            160
# 27304    135.8.60.182  46574   tcp  ftp-data  ...          3            124
# 27661    135.8.60.182  46710   tcp  ftp-data  ...          3            124
# 29041   172.16.115.20     53   udp       dns  ...          1            119
#
#       tunnel_parents ip_proto phase        t_rel y_pred  y_true  \
# 24140              -       17     0  2797.665006      3       0
# 25738              -       17     0  3213.654696      3       0
# 27304              -        6     0  3736.188621      3       0
# 27661              -        6     0  3854.541224      3       0
# 29041              -       17     0  4295.315456      3       0
#
#        hard_violation  soft_violation
# 24140           False           False
# 25738           False           False
# 27304           False           False
# 27661           False           False
# 29041           False           False
#
# [5 rows x 29 columns]
