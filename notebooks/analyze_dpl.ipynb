# %% [markdown]
# # Analyze DARPA Flags Results

# %%
from pathlib import Path
import json
import pickle
from itertools import product

import numpy as np
import pandas as pd

# %%
from analyze import (
    is_hard_violation,
    is_soft_violation,
    mis_metrics,
    plot_mis_predictions
)

# %% [markdown]
# ## Load Original Flows

# %%
# Dataset configuration
dataset = "darpa2000"
scenario = "s1_inside"

# %%
df = pd.read_csv(
    f"../data/interim/{dataset}/{scenario}/flows_labeled/all_flows_labeled.csv"
)

df = df.sort_values("start_time").reset_index(drop=True)
df['t_rel'] = df['start_time'] - df['start_time'].min()

# %%
phase_bounds = (
    df[df['phase'] > 0]
    .groupby('phase')['t_rel']
    .agg(['min', 'max'])
)

phase_start = phase_bounds['min'].to_dict()
phase_end   = phase_bounds['max'].to_dict()

# %%
phase_bounds
# Out:
#                min          max
# phase
# 1      1799.665435  1824.341042
# 2      2790.877254  3333.974143
# 3      4294.134775  4402.837414
# 4      5305.272464  5357.444592
# 5      7478.960660  8383.254878

# %% [markdown]
# ## Load DPL Dataset

# %%
# logic_file = [
#     "darpa_flags",
# ]

# dataset_variant = [
#     "original", 
#     # "resampled",
# ]

# window_sizes = [
#     10, 
#     # 50, 
#     # 100,
# ]

# %%
# Experiment configuration
logic_file = "darpa_flags_ports"
train_mode = "scratch"
dataset_variant = "resampled"
window_size = 10

# %%
dpl_dataset_dir = Path(f"../experiments/{dataset}/{scenario}/deepproblog/{logic_file}/cache/")
cache_file_test = dpl_dataset_dir / f"{logic_file}_{dataset_variant}_w{window_size}_test.pkl"

# %%
# Load DPL dataset
cache = pickle.load(open(cache_file_test, "rb"))
cache_df = pd.DataFrame(cache)
cache_df.head()
# Out:
#    dpl_index  orig_index    start_time          src_ip         dst_ip  sport  \
# 0          0          11  9.524389e+08  172.16.112.100  172.16.115.20   1064
# 1          1          14  9.524389e+08  172.16.112.100  172.16.115.20   1066
# 2          2          18  9.524389e+08  172.16.112.100  172.16.115.20   1070
# 3          3          19  9.524389e+08  172.16.112.100  172.16.115.20   1071
# 4          4          21  9.524389e+08  172.16.112.100  172.16.115.20   1073
#
#    dport  phase                     flags phase_counts   label
# 0     53      0  {1: 0, 2: 0, 3: 0, 4: 0}           {}  benign
# 1     53      0  {1: 0, 2: 0, 3: 0, 4: 0}       {0: 1}  benign
# 2     53      0  {1: 0, 2: 0, 3: 0, 4: 0}       {0: 2}  benign
# 3     53      0  {1: 0, 2: 0, 3: 0, 4: 0}       {0: 3}  benign
# 4     53      0  {1: 0, 2: 0, 3: 0, 4: 0}       {0: 4}  benign

# %% [markdown]
# ## Analyze Results

# %%
results = []

# %%
# for logic, dataset_variant, window_size in product(
#     logic_file,
#     dataset_variant,
#     window_sizes,
# ):
    
errors_dir = f"../experiments/{dataset}/{scenario}/deepproblog/{logic_file}/errors"
experiment_name = f"{logic_file}_{train_mode}_{dataset_variant}_w{window_size}"
# run_id = "20260311_153748"
# run_id = "20260311_160847"
# run_id = "20260312_163325"
# run_id = "20260312_171549"
run_id = "20260312_173806"

errors_file = (
    f"{errors_dir}/"
    f"{experiment_name}_{run_id}.json"
)
    
with open(errors_file) as f:
    errors = json.load(f)

# %%
# Build lookup once
dpl_to_orig = dict(zip(cache_df['dpl_index'], cache_df['orig_index']))

original_indices = []
mis_y_preds = []
mis_y_trues = []

phase_map = {
    "benign": 0,
    "phase1": 1,
    "phase2": 2,
    "phase3": 3,
    "phase4": 4,
    "phase5": 5,
}

for error in errors:
    dpl_index = error['index']

    original_indices.append(dpl_to_orig[dpl_index])
    y_pred = error['predicted']
    y_true = error['actual']
    mis_y_preds.append(phase_map[y_pred])
    mis_y_trues.append(phase_map[y_true])

mis_df = df.loc[original_indices].copy()
mis_df['y_pred'] = mis_y_preds
mis_df['y_true'] = mis_y_trues

# %%
mis_df.head(10)
# Out:
#       flow_id    start_time      end_time    duration          src_ip  sport  \
# 17567  f17534  9.524401e+08  9.524401e+08    0.011254  135.13.216.191  44361
# 20733  f20714  9.524405e+08  9.524405e+08    0.010538  135.13.216.191  44707
# 20734  f20715  9.524405e+08  9.524405e+08    0.011901  135.13.216.191  44708
# 23467  f25337  9.524414e+08  9.524420e+08  661.643033  172.16.112.194  17531
# 23862  f28048  9.524416e+08  9.524426e+08  985.018007   194.7.248.153  43459
# 24138  f24205  9.524417e+08  9.524417e+08   55.105984  172.16.112.194      3
# 24140  f24197  9.524417e+08  9.524417e+08    0.000000    172.16.113.1    123
# 24213  f24189  9.524417e+08  9.524417e+08    0.004042  197.218.177.69  45873
# 24689  f25508  9.524419e+08  9.524420e+08  110.206492  172.16.112.194      3
# 25039  f26221  9.524420e+08  9.524420e+08    0.127205   172.16.116.20   3102
#
#                dst_ip  dport proto service  ...  orig_pkts  orig_ip_bytes  \
# 17567  172.16.112.100     80   tcp    http  ...          5            533
# 20733  172.16.112.100     80   tcp    http  ...          5            537
# 20734  172.16.112.100     80   tcp    http  ...          5            535
# 23467   172.16.112.50     23   tcp       -  ...       3563         144401
# 23862   172.16.115.20     23   tcp       -  ...         62           3261
# 24138  202.77.162.213      3  icmp       -  ...         10           1120
# 24140  172.16.113.255    123   udp     ntp  ...          1             76
# 24213  172.16.112.100     80   tcp    http  ...          5            536
# 24689  202.77.162.213      3  icmp       -  ...         18           2016
# 25039  172.16.112.100    139   tcp       -  ...          8            990
#
#       resp_pkts resp_ip_bytes tunnel_parents  ip_proto phase        t_rel  \
# 17567         4          1266              -         6     0  1189.171837
# 20733         5          2929              -         6     0  1561.803985
# 20734         5          2738              -         6     0  1561.825524
# 23467      1793         74832              -         6     0  2461.809980
# 23862        32          1711              -         6     0  2703.913353
# 24138         0             0              -         1     2  2791.018877
# 24140         0             0              -        17     0  2797.665006
# 24213         4          1571              -         6     0  2841.315436
# 24689         0             0              -         1     2  3033.182087
# 25039        12          1408              -         6     0  3063.664460
#
#        y_pred  y_true
# 17567       1       0
# 20733       1       0
# 20734       1       0
# 23467       2       0
# 23862       2       0
# 24138       0       2
# 24140       3       0
# 24213       3       0
# 24689       0       2
# 25039       3       0
#
# [10 rows x 27 columns]

# %%
# --- Compute violation categories ---
wrong, hard, soft, plausible = mis_metrics(mis_df, phase_start)

total_wrong = len(wrong)
hard_rate = len(hard) / total_wrong if total_wrong > 0 else 0
soft_rate = len(soft) / total_wrong if total_wrong > 0 else 0

# --- Collect everything ---
results.append({
    "model": f"{experiment_name}",
    # "accuracy": metrics["accuracy"],
    # "precision" : metrics["precision"],
    # "recall" : metrics["recall"], 
    # "f1": metrics["f1"],
    "total_wrong": total_wrong,
    "hard_violations": len(hard),
    "soft_violations": len(soft),
    "hard_rate": hard_rate,
    "soft_rate": soft_rate,
})

# Create plots
out_dir = Path(f"../reports/{logic_file}")

plot_mis_predictions(
    df, 
    phase_bounds, 
    plausible, 
    soft, 
    hard, 
    total_wrong, 
    soft_rate, 
    hard_rate, 
    experiment_name, 
    out_dir
)

# %%
mis_df
# Out:
#         flow_id    start_time      end_time    duration          src_ip  \
# 17567    f17534  9.524401e+08  9.524401e+08    0.011254  135.13.216.191
# 20733    f20714  9.524405e+08  9.524405e+08    0.010538  135.13.216.191
# 20734    f20715  9.524405e+08  9.524405e+08    0.011901  135.13.216.191
# 23467    f25337  9.524414e+08  9.524420e+08  661.643033  172.16.112.194
# 23862    f28048  9.524416e+08  9.524426e+08  985.018007   194.7.248.153
# ...         ...           ...           ...         ...             ...
# 115033  f115007  9.524471e+08  9.524471e+08    0.078300    172.16.115.5
# 115037  f115009  9.524471e+08  9.524471e+08    0.072933    172.16.115.5
# 115298  f115256  9.524473e+08  9.524473e+08    0.031198    172.16.115.5
# 115300  f115257  9.524473e+08  9.524473e+08    0.053366    172.16.115.5
# 115304  f115259  9.524473e+08  9.524473e+08    0.078039    172.16.115.5
#
#         sport          dst_ip  dport proto service  ...  resp_pkts  \
# 17567   44361  172.16.112.100     80   tcp    http  ...          4
# 20733   44707  172.16.112.100     80   tcp    http  ...          5
# 20734   44708  172.16.112.100     80   tcp    http  ...          5
# 23467   17531   172.16.112.50     23   tcp       -  ...       1793
# 23862   43459   172.16.115.20     23   tcp       -  ...         32
# ...       ...             ...    ...   ...     ...  ...        ...
# 115033  24713     131.84.1.31     80   tcp    http  ...          9
# 115037  24715     131.84.1.31     80   tcp    http  ...         11
# 115298  26715     131.84.1.31     80   tcp    http  ...          4
# 115300  26716     131.84.1.31     80   tcp    http  ...          9
# 115304  26753     131.84.1.31     80   tcp    http  ...         13
#
#         resp_ip_bytes tunnel_parents ip_proto phase        t_rel y_pred  \
# 17567            1266              -        6     0  1189.171837      1
# 20733            2929              -        6     0  1561.803985      1
# 20734            2738              -        6     0  1561.825524      1
# 23467           74832              -        6     0  2461.809980      2
# 23862            1711              -        6     0  2703.913353      2
# ...               ...            ...      ...   ...          ...    ...
# 115033           7092              -        6     5  8200.677959      0
# 115037          13067              -        6     5  8200.840443      0
# 115298           2432              -        6     5  8382.941330      0
# 115300           6530              -        6     5  8382.975029      0
# 115304          15038              -        6     5  8383.129199      0
#
#         y_true  hard_violation  soft_violation
# 17567        0           False           False
# 20733        0           False           False
# 20734        0           False           False
# 23467        0           False           False
# 23862        0           False           False
# ...        ...             ...             ...
# 115033       5           False           False
# 115037       5           False           False
# 115298       5           False           False
# 115300       5           False           False
# 115304       5           False           False
#
# [67 rows x 29 columns]

# %%
mis_pred_2 = mis_df[mis_df["y_pred"] == 2]
mis_pred_2
# Out:
#       flow_id    start_time      end_time    duration          src_ip  sport  \
# 23467  f25337  9.524414e+08  9.524420e+08  661.643033  172.16.112.194  17531
# 23862  f28048  9.524416e+08  9.524426e+08  985.018007   194.7.248.153  43459
#
#               dst_ip  dport proto service  ...  resp_pkts  resp_ip_bytes  \
# 23467  172.16.112.50     23   tcp       -  ...       1793          74832
# 23862  172.16.115.20     23   tcp       -  ...         32           1711
#
#       tunnel_parents ip_proto phase        t_rel y_pred  y_true  \
# 23467              -        6     0  2461.809980      2       0
# 23862              -        6     0  2703.913353      2       0
#
#        hard_violation  soft_violation
# 23467           False           False
# 23862           False           False
#
# [2 rows x 29 columns]
