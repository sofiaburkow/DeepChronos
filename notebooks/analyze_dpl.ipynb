# %% [markdown]
# # Analyze DARPA Flags Results

# %%
from pathlib import Path
import json
import pickle
from itertools import product

import numpy as np
import pandas as pd

# %%
from analyze import (
    mis_metrics,
    plot_mis_predictions
)

# %% [markdown]
# ## Config

# %%
# Dataset configuration
dataset = "darpa2000"
scenario = "s1_inside"

# %%
# Experiment configuration
logic_file = "darpa_simple"
train_mode = "scratch" # "scratch" or "pretrained"
dataset_variant = "down" # "original" or "resampled"
window_size = 10

# run_id = "20260323_090348"
run_id = "20260325_124841"

# %% [markdown]
# ## Load Original Flows

# %%
df = pd.read_csv(
    f"../data/interim/{dataset}/{scenario}/flows_labeled/all_flows_labeled.csv"
)

df = df.sort_values("start_time").reset_index(drop=True)
df['t_rel'] = df['start_time'] - df['start_time'].min()

# %%
phase_bounds = (
    df[df['phase'] > 0]
    .groupby('phase')['t_rel']
    .agg(['min', 'max'])
)

phase_start = phase_bounds['min'].to_dict()
phase_end   = phase_bounds['max'].to_dict()

# %%
phase_bounds
# Out:
#                min          max
# phase
# 1      1799.665435  1824.341042
# 2      2790.877254  3333.974143
# 3      4294.134775  4402.837414
# 4      5305.272464  5357.444592
# 5      7478.960660  8383.254878

# %% [markdown]
# ## Load DPL Dataset

# %%
dpl_dataset_dir = Path(f"../experiments/{dataset}/{scenario}/deepproblog/{logic_file}/cache/")
cache_file_test = dpl_dataset_dir / f"{logic_file}_{dataset_variant}_w{window_size}_test.pkl"

# %%
# Load DPL dataset
cache = pickle.load(open(cache_file_test, "rb"))
cache_df = pd.DataFrame(cache)
cache_df.head()
# Out:
#    dpl_index  orig_index  phase                     flags  next  local_orig  \
# 0          0          11      0  {1: 0, 2: 0, 3: 0, 4: 0}     1           1
# 1          1          14      0  {1: 0, 2: 0, 3: 0, 4: 0}     1           1
# 2          2          18      0  {1: 0, 2: 0, 3: 0, 4: 0}     1           1
# 3          3          19      0  {1: 0, 2: 0, 3: 0, 4: 0}     1           1
# 4          4          21      0  {1: 0, 2: 0, 3: 0, 4: 0}     1           1
#
#    local_resp  dport  protocol  ddos_count  ddos_rate  unique_sources   label
# 0           1     53        17           1       0.05               1  benign
# 1           1     53        17           2       0.10               1  benign
# 2           1     53        17           3       0.15               1  benign
# 3           1     53        17           4       0.20               1  benign
# 4           1     53        17           5       0.25               1  benign

# %% [markdown]
# ## Analyze Results

# %%
results = []

# %%
# for logic, dataset_variant, window_size in product(
#     logic_file,
#     dataset_variant,
#     window_sizes,
# ):
    
errors_dir = f"../experiments/{dataset}/{scenario}/deepproblog/{logic_file}/errors"
experiment_name = f"{logic_file}_{train_mode}_{dataset_variant}_w{window_size}"

errors_file = (
    f"{errors_dir}/"
    f"{experiment_name}_{run_id}.json"
)
    
with open(errors_file) as f:
    errors = json.load(f)

# %%
# Build lookup once
dpl_to_orig = dict(zip(cache_df['dpl_index'], cache_df['orig_index']))

original_indices = []
mis_y_preds = []
mis_y_trues = []

phase_map = {
    "benign": 0,
    "phase1": 1,
    "phase2": 2,
    "phase3": 3,
    "phase4": 4,
    "phase5": 5,
}

for error in errors:
    dpl_index = error['index']

    original_indices.append(dpl_to_orig[dpl_index])
    y_pred = error['predicted']
    y_true = error['actual']
    mis_y_preds.append(phase_map[y_pred])
    mis_y_trues.append(phase_map[y_true])

mis_df = df.loc[original_indices].copy()
mis_df['y_pred'] = mis_y_preds
mis_df['y_true'] = mis_y_trues

# %%
mis_df.head(10)
# Out:
#        flow_id    start_time      end_time     duration          src_ip  \
# 24136   f24195  9.524417e+08  9.524417e+08     0.121346  202.77.162.213
# 24138   f24205  9.524417e+08  9.524417e+08    55.105984  172.16.112.194
# 24688   f25405  9.524419e+08  9.524420e+08    55.095633  202.77.162.213
# 24689   f25508  9.524419e+08  9.524420e+08   110.206492  172.16.112.194
# 25740   f26008  9.524421e+08  9.524422e+08    55.104831  172.16.112.100
# 25977   f26288  9.524422e+08  9.524422e+08    55.093929  172.16.112.105
# 26061   f26394  9.524422e+08  9.524423e+08    55.097203  172.16.112.194
# 29065   f29034  9.524432e+08  9.524432e+08     1.605300  202.77.162.213
# 30791  f125815  9.524438e+08  9.524505e+08  6746.255378  197.182.91.233
# 31975   f31955  9.524442e+08  9.524442e+08     0.001083   172.16.112.20
#
#        sport          dst_ip  dport proto service  ...  orig_pkts  \
# 24136  54792   172.16.115.20  32773   udp       -  ...          1
# 24138      3  202.77.162.213      3  icmp       -  ...         10
# 24688  55485  172.16.113.105    111   udp       -  ...         12
# 24689      3  202.77.162.213      3  icmp       -  ...         18
# 25740      3  202.77.162.213      3  icmp       -  ...         12
# 25977      3  202.77.162.213      3  icmp       -  ...         12
# 26061      3  202.77.162.213      3  icmp       -  ...         12
# 29065  46959   172.16.115.20     23   tcp       -  ...         13
# 30791  47288   172.16.115.20     23   tcp       -  ...       3005
# 31975   1572   172.16.115.20     53   udp     dns  ...          1
#
#        orig_ip_bytes resp_pkts resp_ip_bytes tunnel_parents  ip_proto phase  \
# 24136            100         1            52              -        17     2
# 24138           1120         0             0              -         1     2
# 24688           1008         0             0              -        17     2
# 24689           2016         0             0              -         1     2
# 25740            672         0             0              -         1     2
# 25977            672         0             0              -         1     2
# 26061           1344         0             0              -         1     2
# 29065            726        13           839              -         6     3
# 30791         157848      1555         90717              -         6     0
# 31975             73         1           160              -        17     0
#
#              t_rel  y_pred  y_true
# 24136  2790.882799       0       2
# 24138  2791.018877       0       2
# 24688  3033.181850       0       2
# 24689  3033.182087       0       2
# 25740  3213.724917       0       2
# 25977  3273.859441       0       2
# 26061  3333.974143       0       2
# 29065  4314.762450       0       3
# 30791  4896.435225       4       0
# 31975  5307.725461       5       0
#
# [10 rows x 27 columns]

# %%
# --- Compute violation categories ---
wrong, hard, soft, plausible = mis_metrics(mis_df, phase_start)

total_wrong = len(wrong)
hard_rate = len(hard) / total_wrong if total_wrong > 0 else 0
soft_rate = len(soft) / total_wrong if total_wrong > 0 else 0

# --- Collect everything ---
results.append({
    "model": f"{experiment_name}",
    # "accuracy": metrics["accuracy"],
    # "precision" : metrics["precision"],
    # "recall" : metrics["recall"], 
    # "f1": metrics["f1"],
    "total_wrong": total_wrong,
    "hard_violations": len(hard),
    "soft_violations": len(soft),
    "hard_rate": hard_rate,
    "soft_rate": soft_rate,
})

# Create plots
out_dir = Path(f"../reports/{logic_file}")

plot_mis_predictions(
    df, 
    phase_bounds, 
    plausible, 
    soft, 
    hard, 
    total_wrong, 
    soft_rate, 
    hard_rate, 
    experiment_name, 
    out_dir
)

# %%
mis_df
# Out:
#         flow_id    start_time      end_time    duration          src_ip  \
# 24136    f24195  9.524417e+08  9.524417e+08    0.121346  202.77.162.213
# 24138    f24205  9.524417e+08  9.524417e+08   55.105984  172.16.112.194
# 24688    f25405  9.524419e+08  9.524420e+08   55.095633  202.77.162.213
# 24689    f25508  9.524419e+08  9.524420e+08  110.206492  172.16.112.194
# 25740    f26008  9.524421e+08  9.524422e+08   55.104831  172.16.112.100
# ...         ...           ...           ...         ...             ...
# 125814  f125748  9.524505e+08  9.524505e+08    0.049206    172.16.115.5
# 125815  f125779  9.524505e+08  9.524505e+08    0.005121   172.16.115.20
# 125819  f125785  9.524505e+08  9.524505e+08    0.004026   194.7.248.153
# 125820  f125784  9.524505e+08  9.524505e+08    0.005069   194.7.248.153
# 125822  f125782  9.524505e+08  9.524505e+08    0.005026   194.7.248.153
#
#         sport          dst_ip  dport proto service  ...  resp_pkts  \
# 24136   54792   172.16.115.20  32773   udp       -  ...          1
# 24138       3  202.77.162.213      3  icmp       -  ...          0
# 24688   55485  172.16.113.105    111   udp       -  ...          0
# 24689       3  202.77.162.213      3  icmp       -  ...          0
# 25740       3  202.77.162.213      3  icmp       -  ...          0
# ...       ...             ...    ...   ...     ...  ...        ...
# 125814  12769    206.39.184.2     80   tcp    http  ...          7
# 125815  32780    192.168.1.20     53   udp     dns  ...          1
# 125819  52675  172.16.112.100     80   tcp    http  ...          4
# 125820  52676  172.16.112.100     80   tcp    http  ...          5
# 125822  52678  172.16.112.100     80   tcp    http  ...          5
#
#         resp_ip_bytes tunnel_parents ip_proto phase         t_rel y_pred  \
# 24136              52              -       17     2   2790.882799      0
# 24138               0              -        1     2   2791.018877      0
# 24688               0              -       17     2   3033.181850      0
# 24689               0              -        1     2   3033.182087      0
# 25740               0              -        1     2   3213.724917      0
# ...               ...            ...      ...   ...           ...    ...
# 125814           3944              -        6     0  11641.904935      5
# 125815             89              -       17     0  11646.012095      5
# 125819           1571              -        6     0  11649.662103      5
# 125820           2929              -        6     0  11649.677831      5
# 125822           2738              -        6     0  11649.709793      5
#
#         y_true  hard_violation  soft_violation
# 24136        2           False           False
# 24138        2           False           False
# 24688        2           False           False
# 24689        2           False           False
# 25740        2           False           False
# ...        ...             ...             ...
# 125814       0           False           False
# 125815       0           False           False
# 125819       0           False           False
# 125820       0           False           False
# 125822       0           False           False
#
# [8100 rows x 29 columns]

# %%
def false_positives(df, phase):
    return df[(df["y_true"] != phase) & (df["y_pred"] == phase)]

# %%
def false_negatives(df, phase):
    return df[(df["y_true"] == phase) & (df["y_pred"] != phase)]

# %%
def true_positives(df, phase):
    return df[(df["y_true"] == phase) & (df["y_pred"] == phase)]

# %%
df_fp_2 = false_positives(mis_df, 2)
df_fp_2
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_fn_2 = false_negatives(mis_df, 2)
df_fn_2
# Out:
#       flow_id    start_time      end_time    duration          src_ip  sport  \
# 24136  f24195  9.524417e+08  9.524417e+08    0.121346  202.77.162.213  54792
# 24138  f24205  9.524417e+08  9.524417e+08   55.105984  172.16.112.194      3
# 24688  f25405  9.524419e+08  9.524420e+08   55.095633  202.77.162.213  55485
# 24689  f25508  9.524419e+08  9.524420e+08  110.206492  172.16.112.194      3
# 25740  f26008  9.524421e+08  9.524422e+08   55.104831  172.16.112.100      3
# 25977  f26288  9.524422e+08  9.524422e+08   55.093929  172.16.112.105      3
# 26061  f26394  9.524422e+08  9.524423e+08   55.097203  172.16.112.194      3
#
#                dst_ip  dport proto service  ...  resp_pkts  resp_ip_bytes  \
# 24136   172.16.115.20  32773   udp       -  ...          1             52
# 24138  202.77.162.213      3  icmp       -  ...          0              0
# 24688  172.16.113.105    111   udp       -  ...          0              0
# 24689  202.77.162.213      3  icmp       -  ...          0              0
# 25740  202.77.162.213      3  icmp       -  ...          0              0
# 25977  202.77.162.213      3  icmp       -  ...          0              0
# 26061  202.77.162.213      3  icmp       -  ...          0              0
#
#       tunnel_parents ip_proto phase        t_rel y_pred  y_true  \
# 24136              -       17     2  2790.882799      0       2
# 24138              -        1     2  2791.018877      0       2
# 24688              -       17     2  3033.181850      0       2
# 24689              -        1     2  3033.182087      0       2
# 25740              -        1     2  3213.724917      0       2
# 25977              -        1     2  3273.859441      0       2
# 26061              -        1     2  3333.974143      0       2
#
#        hard_violation  soft_violation
# 24136           False           False
# 24138           False           False
# 24688           False           False
# 24689           False           False
# 25740           False           False
# 25977           False           False
# 26061           False           False
#
# [7 rows x 29 columns]

# %%
df_fn_2["local_orig"]
df_fn_2["local_resp"]
# Out:
# 24136    T
# 24138    F
# 24688    T
# 24689    F
# 25740    F
# 25977    F
# 26061    F
# Name: local_resp, dtype: object

# %%
df_tp_2 = true_positives(mis_df, 2)
df_tp_2
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_fn_3 = false_negatives(mis_df, 3)
df_fn_3
# Out:
#       flow_id    start_time      end_time  duration          src_ip  sport  \
# 29065  f29034  9.524432e+08  9.524432e+08    1.6053  202.77.162.213  46959
#
#               dst_ip  dport proto service  ...  resp_pkts  resp_ip_bytes  \
# 29065  172.16.115.20     23   tcp       -  ...         13            839
#
#       tunnel_parents ip_proto phase       t_rel y_pred  y_true  \
# 29065              -        6     3  4314.76245      0       3
#
#        hard_violation  soft_violation
# 29065           False           False
#
# [1 rows x 29 columns]

# %%
df_fp_3 = false_positives(mis_df, 3)
df_fp_3
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_fn_4 = false_negatives(mis_df, 4)
df_fn_4
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_fp_4 = false_positives(mis_df, 4)
df_fp_4
# Out:
#        flow_id    start_time      end_time     duration          src_ip  \
# 30791  f125815  9.524438e+08  9.524505e+08  6746.255378  197.182.91.233
#
#        sport         dst_ip  dport proto service  ...  resp_pkts  \
# 30791  47288  172.16.115.20     23   tcp       -  ...       1555
#
#        resp_ip_bytes tunnel_parents ip_proto phase        t_rel y_pred  \
# 30791          90717              -        6     0  4896.435225      4
#
#        y_true  hard_violation  soft_violation
# 30791       0           False           False
#
# [1 rows x 29 columns]

# %%
df_fp_4["dport"].value_counts()
# Out:
# dport
# 23    1
# Name: count, dtype: int64

# %%
df_fn_5 = false_negatives(mis_df, 5)
df_fn_5
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]
