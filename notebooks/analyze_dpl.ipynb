# %% [markdown]
# # Analyze DARPA Flags Results

# %%
from pathlib import Path
import json
import pickle
from itertools import product

import numpy as np
import pandas as pd

# %%
from analyze import (
    mis_metrics,
    plot_mis_predictions
)

# %% [markdown]
# ## Config

# %%
# Dataset configuration
dataset = "darpa2000"
scenario = "s1_dmz"

# %%
# Experiment configuration
logic_file = "darpa_simple"
train_mode = "scratch" # "scratch" or "pretrained"
dataset_variant = "resampled" # "original" or "resampled"
window_size = 10

# run_id = "20260323_090348"
run_id = "20260323_151449"

# %% [markdown]
# ## Load Original Flows

# %%
df = pd.read_csv(
    f"../data/interim/{dataset}/{scenario}/flows_labeled/all_flows_labeled.csv"
)

df = df.sort_values("start_time").reset_index(drop=True)
df['t_rel'] = df['start_time'] - df['start_time'].min()

# %%
phase_bounds = (
    df[df['phase'] > 0]
    .groupby('phase')['t_rel']
    .agg(['min', 'max'])
)

phase_start = phase_bounds['min'].to_dict()
phase_end   = phase_bounds['max'].to_dict()

# %%
phase_bounds
# Out:
#                min          max
# phase
# 1      1839.954655  1865.931020
# 2      2771.148243  3374.368529
# 3      4334.529144  4443.235439
# 4      5345.666392  5397.844729
# 5      7519.353413  8423.658996

# %% [markdown]
# ## Load DPL Dataset

# %%
dpl_dataset_dir = Path(f"../experiments/{dataset}/{scenario}/deepproblog/{logic_file}/cache/")
cache_file_test = dpl_dataset_dir / f"{logic_file}_{dataset_variant}_w{window_size}_test.pkl"

# %%
# Load DPL dataset
cache = pickle.load(open(cache_file_test, "rb"))
cache_df = pd.DataFrame(cache)
cache_df.head()
# Out:
#    dpl_index  orig_index  phase                     flags  ddos_count  \
# 0          0          10      0  {1: 0, 2: 0, 3: 0, 4: 0}           1
# 1          1          13      0  {1: 0, 2: 0, 3: 0, 4: 0}           2
# 2          2          14      0  {1: 0, 2: 0, 3: 0, 4: 0}           3
# 3          3          15      0  {1: 0, 2: 0, 3: 0, 4: 0}           1
# 4          4          16      0  {1: 0, 2: 0, 3: 0, 4: 0}           1
#
#    ddos_rate  unique_sources   label
# 0       0.05               1  benign
# 1       0.10               1  benign
# 2       0.15               1  benign
# 3       0.05               1  benign
# 4       0.05               1  benign

# %% [markdown]
# ## Analyze Results

# %%
results = []

# %%
# for logic, dataset_variant, window_size in product(
#     logic_file,
#     dataset_variant,
#     window_sizes,
# ):
    
errors_dir = f"../experiments/{dataset}/{scenario}/deepproblog/{logic_file}/errors"
experiment_name = f"{logic_file}_{train_mode}_{dataset_variant}_w{window_size}"

errors_file = (
    f"{errors_dir}/"
    f"{experiment_name}_{run_id}.json"
)
    
with open(errors_file) as f:
    errors = json.load(f)

# %%
# Build lookup once
dpl_to_orig = dict(zip(cache_df['dpl_index'], cache_df['orig_index']))

original_indices = []
mis_y_preds = []
mis_y_trues = []

phase_map = {
    "benign": 0,
    "phase1": 1,
    "phase2": 2,
    "phase3": 3,
    "phase4": 4,
    "phase5": 5,
}

for error in errors:
    dpl_index = error['index']

    original_indices.append(dpl_to_orig[dpl_index])
    y_pred = error['predicted']
    y_true = error['actual']
    mis_y_preds.append(phase_map[y_pred])
    mis_y_trues.append(phase_map[y_true])

mis_df = df.loc[original_indices].copy()
mis_df['y_pred'] = mis_y_preds
mis_df['y_true'] = mis_y_trues

# %%
mis_df.head(10)
# Out:
#       flow_id    start_time      end_time     duration          src_ip  sport  \
# 4606    f4569  9.524432e+08  9.524432e+08     4.222506  202.77.162.213   1497
# 4611    f4574  9.524432e+08  9.524432e+08     8.201315  202.77.162.213   1498
# 4634    f4588  9.524432e+08  9.524433e+08     8.417312  202.77.162.213   1505
# 4670    f4629  9.524433e+08  9.524433e+08     8.416794  202.77.162.213   1507
# 4696    f4679  9.524433e+08  9.524433e+08     8.280800  202.77.162.213   1534
# 5180   f45437  9.524438e+08  9.524506e+08  6808.971401  197.182.91.233  13449
# 5516    f5910  9.524442e+08  9.524442e+08     0.001277   172.16.112.10   1023
# 7593    f7570  9.524465e+08  9.524465e+08     0.000000     131.84.1.31  31938
# 7595    f7572  9.524465e+08  9.524465e+08     0.000000     131.84.1.31  24037
# 41504  f41482  9.524465e+08  9.524465e+08     0.012643  197.182.91.233  20841
#
#                dst_ip  dport proto service  ...  orig_pkts  orig_ip_bytes  \
# 4606    172.16.114.10     23   tcp       -  ...         13            566
# 4611    172.16.114.10     23   tcp       -  ...         13            566
# 4634    172.16.114.20     23   tcp       -  ...         14            606
# 4670    172.16.114.30     23   tcp       -  ...         14            606
# 4696    172.16.112.50     23   tcp       -  ...         13            566
# 5180    172.16.115.20     23   tcp       -  ...       3171         128508
# 5516   202.77.162.213   1018   tcp       -  ...          2            100
# 7593     61.56.80.155   4940   tcp       -  ...          1             40
# 7595      45.4.65.127   4942   tcp       -  ...          1             40
# 41504  172.16.112.100     80   tcp    http  ...          5            447
#
#       resp_pkts resp_ip_bytes tunnel_parents  ip_proto phase        t_rel  \
# 4606         13           639              -         6     3  4360.974895
# 4611         13           639              -         6     3  4365.161746
# 4634         14           679              -         6     3  4390.477365
# 4670         14           679              -         6     3  4407.658128
# 4696         12           627              -         6     3  4436.957886
# 5180       1646         75839              -         6     0  4936.829975
# 5516          1            44              -         6     4  5381.815260
# 7593          0             0              -         6     5  7615.068855
# 7595          0             0              -         6     5  7615.069964
# 41504         4          1571              -         6     0  7628.151773
#
#        y_pred  y_true
# 4606        0       3
# 4611        0       3
# 4634        0       3
# 4670        0       3
# 4696        0       3
# 5180        4       0
# 5516        0       4
# 7593        0       5
# 7595        0       5
# 41504       5       0
#
# [10 rows x 27 columns]

# %%
# --- Compute violation categories ---
wrong, hard, soft, plausible = mis_metrics(mis_df, phase_start)

total_wrong = len(wrong)
hard_rate = len(hard) / total_wrong if total_wrong > 0 else 0
soft_rate = len(soft) / total_wrong if total_wrong > 0 else 0

# --- Collect everything ---
results.append({
    "model": f"{experiment_name}",
    # "accuracy": metrics["accuracy"],
    # "precision" : metrics["precision"],
    # "recall" : metrics["recall"], 
    # "f1": metrics["f1"],
    "total_wrong": total_wrong,
    "hard_violations": len(hard),
    "soft_violations": len(soft),
    "hard_rate": hard_rate,
    "soft_rate": soft_rate,
})

# Create plots
out_dir = Path(f"../reports/{logic_file}")

plot_mis_predictions(
    df, 
    phase_bounds, 
    plausible, 
    soft, 
    hard, 
    total_wrong, 
    soft_rate, 
    hard_rate, 
    experiment_name, 
    out_dir
)

# %%
mis_df
# Out:
#       flow_id    start_time      end_time     duration          src_ip  sport  \
# 4606    f4569  9.524432e+08  9.524432e+08     4.222506  202.77.162.213   1497
# 4611    f4574  9.524432e+08  9.524432e+08     8.201315  202.77.162.213   1498
# 4634    f4588  9.524432e+08  9.524433e+08     8.417312  202.77.162.213   1505
# 4670    f4629  9.524433e+08  9.524433e+08     8.416794  202.77.162.213   1507
# 4696    f4679  9.524433e+08  9.524433e+08     8.280800  202.77.162.213   1534
# 5180   f45437  9.524438e+08  9.524506e+08  6808.971401  197.182.91.233  13449
# 5516    f5910  9.524442e+08  9.524442e+08     0.001277   172.16.112.10   1023
# 7593    f7570  9.524465e+08  9.524465e+08     0.000000     131.84.1.31  31938
# 7595    f7572  9.524465e+08  9.524465e+08     0.000000     131.84.1.31  24037
# 41504  f41482  9.524465e+08  9.524465e+08     0.012643  197.182.91.233  20841
# 41506  f41484  9.524465e+08  9.524465e+08     0.013362  197.182.91.233  20905
# 41508  f41486  9.524465e+08  9.524465e+08     0.011750  197.182.91.233  21038
# 41890  f41865  9.524469e+08  9.524469e+08     0.025486    172.16.115.5  49591
# 41895  f41870  9.524469e+08  9.524469e+08     0.048682    172.16.115.5  49596
# 41904  f41880  9.524470e+08  9.524470e+08     0.032940  172.16.116.201  49601
# 41906  f41882  9.524470e+08  9.524470e+08     0.049896  172.16.116.201  49603
# 41907  f41883  9.524470e+08  9.524470e+08     0.076223  172.16.116.201  49604
# 41908  f41884  9.524470e+08  9.524470e+08     0.066442  172.16.116.201  49605
# 41910  f41886  9.524470e+08  9.524470e+08     0.045628  172.16.116.201  49607
# 41911  f41888  9.524470e+08  9.524470e+08     0.065035    172.16.115.5  49608
# 41912  f41889  9.524470e+08  9.524470e+08     0.045049    172.16.115.5  49609
# 41914  f41891  9.524470e+08  9.524470e+08     0.133419  172.16.116.201  49611
# 42023  f41997  9.524471e+08  9.524471e+08     0.054359    172.16.115.5  49699
# 42114  f42088  9.524473e+08  9.524473e+08     0.025293    172.16.115.5  49777
# 42115  f42089  9.524473e+08  9.524473e+08     0.048319    172.16.115.5  49778
# 42116  f42090  9.524473e+08  9.524473e+08     0.073494    172.16.115.5  49779
#
#                dst_ip  dport proto service  ...  resp_pkts  resp_ip_bytes  \
# 4606    172.16.114.10     23   tcp       -  ...         13            639
# 4611    172.16.114.10     23   tcp       -  ...         13            639
# 4634    172.16.114.20     23   tcp       -  ...         14            679
# 4670    172.16.114.30     23   tcp       -  ...         14            679
# 4696    172.16.112.50     23   tcp       -  ...         12            627
# 5180    172.16.115.20     23   tcp       -  ...       1646          75839
# 5516   202.77.162.213   1018   tcp       -  ...          1             44
# 7593     61.56.80.155   4940   tcp       -  ...          0              0
# 7595      45.4.65.127   4942   tcp       -  ...          0              0
# 41504  172.16.112.100     80   tcp    http  ...          4           1571
# 41506  172.16.112.100     80   tcp    http  ...          4           2698
# 41508  172.16.112.100     80   tcp    http  ...          4           1266
# 41890     131.84.1.31     80   tcp    http  ...          5           2472
# 41895     131.84.1.31     80   tcp    http  ...          9           6321
# 41904     131.84.1.31     80   tcp    http  ...          6           4445
# 41906     131.84.1.31     80   tcp    http  ...          9           6530
# 41907     131.84.1.31     80   tcp    http  ...         19          21877
# 41908     131.84.1.31     80   tcp    http  ...         13          15038
# 41910     131.84.1.31     80   tcp    http  ...          9           6321
# 41911     131.84.1.31     80   tcp    http  ...          7           3592
# 41912     131.84.1.31     80   tcp    http  ...          9           8032
# 41914     131.84.1.31     80   tcp    http  ...         30          38457
# 42023     131.84.1.31     80   tcp    http  ...          6           2035
# 42114     131.84.1.31     80   tcp    http  ...          5           2472
# 42115     131.84.1.31     80   tcp    http  ...          9           6530
# 42116     131.84.1.31     80   tcp    http  ...         19          21877
#
#       tunnel_parents ip_proto phase        t_rel y_pred  y_true  \
# 4606               -        6     3  4360.974895      0       3
# 4611               -        6     3  4365.161746      0       3
# 4634               -        6     3  4390.477365      0       3
# 4670               -        6     3  4407.658128      0       3
# 4696               -        6     3  4436.957886      0       3
# 5180               -        6     0  4936.829975      4       0
# 5516               -        6     4  5381.815260      0       4
# 7593               -        6     5  7615.068855      0       5
# 7595               -        6     5  7615.069964      0       5
# 41504              -        6     0  7628.151773      5       0
# 41506              -        6     0  7628.182539      5       0
# 41508              -        6     0  7628.214077      5       0
# 41890              -        6     5  8080.801671      0       5
# 41895              -        6     5  8081.114527      0       5
# 41904              -        6     5  8130.681222      0       5
# 41906              -        6     5  8130.763954      0       5
# 41907              -        6     5  8130.829802      0       5
# 41908              -        6     5  8130.929721      0       5
# 41910              -        6     5  8131.065889      0       5
# 41911              -        6     5  8143.579857      0       5
# 41912              -        6     5  8143.659630      0       5
# 41914              -        6     5  8148.355546      0       5
# 42023              -        6     5  8282.952414      0       5
# 42114              -        6     5  8423.345602      0       5
# 42115              -        6     5  8423.379288      0       5
# 42116              -        6     5  8423.435351      0       5
#
#        hard_violation  soft_violation
# 4606            False           False
# 4611            False           False
# 4634            False           False
# 4670            False           False
# 4696            False           False
# 5180            False           False
# 5516            False           False
# 7593            False           False
# 7595            False           False
# 41504           False           False
# 41506           False           False
# 41508           False           False
# 41890           False           False
# 41895           False           False
# 41904           False           False
# 41906           False           False
# 41907           False           False
# 41908           False           False
# 41910           False           False
# 41911           False           False
# 41912           False           False
# 41914           False           False
# 42023           False           False
# 42114           False           False
# 42115           False           False
# 42116           False           False
#
# [26 rows x 29 columns]

# %%
def false_positives(df, phase):
    return df[(df["y_true"] != phase) & (df["y_pred"] == phase)]

# %%
def false_negatives(df, phase):
    return df[(df["y_true"] == phase) & (df["y_pred"] != phase)]

# %%
def true_positives(df, phase):
    return df[(df["y_true"] == phase) & (df["y_pred"] == phase)]

# %%
df_fp_2 = false_positives(mis_df, 2)
df_fp_2
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_fn_2 = false_negatives(mis_df, 2)
df_fn_2
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_fn_2["local_orig"]
df_fn_2["local_resp"]
# Out:
# Series([], Name: local_resp, dtype: object)

# %%
df_tp_2 = true_positives(mis_df, 2)
df_tp_2
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_fn_3 = false_negatives(mis_df, 3)
df_fn_3
# Out:
#      flow_id    start_time      end_time  duration          src_ip  sport  \
# 4606   f4569  9.524432e+08  9.524432e+08  4.222506  202.77.162.213   1497
# 4611   f4574  9.524432e+08  9.524432e+08  8.201315  202.77.162.213   1498
# 4634   f4588  9.524432e+08  9.524433e+08  8.417312  202.77.162.213   1505
# 4670   f4629  9.524433e+08  9.524433e+08  8.416794  202.77.162.213   1507
# 4696   f4679  9.524433e+08  9.524433e+08  8.280800  202.77.162.213   1534
#
#              dst_ip  dport proto service  ...  resp_pkts  resp_ip_bytes  \
# 4606  172.16.114.10     23   tcp       -  ...         13            639
# 4611  172.16.114.10     23   tcp       -  ...         13            639
# 4634  172.16.114.20     23   tcp       -  ...         14            679
# 4670  172.16.114.30     23   tcp       -  ...         14            679
# 4696  172.16.112.50     23   tcp       -  ...         12            627
#
#      tunnel_parents ip_proto phase        t_rel y_pred  y_true  \
# 4606              -        6     3  4360.974895      0       3
# 4611              -        6     3  4365.161746      0       3
# 4634              -        6     3  4390.477365      0       3
# 4670              -        6     3  4407.658128      0       3
# 4696              -        6     3  4436.957886      0       3
#
#       hard_violation  soft_violation
# 4606           False           False
# 4611           False           False
# 4634           False           False
# 4670           False           False
# 4696           False           False
#
# [5 rows x 29 columns]

# %%
df_fp_3 = false_positives(mis_df, 3)
df_fp_3
# Out:
# Empty DataFrame
# Columns: [flow_id, start_time, end_time, duration, src_ip, sport, dst_ip, dport, proto, service, orig_bytes, resp_bytes, conn_state, local_orig, local_resp, missed_bytes, history, orig_pkts, orig_ip_bytes, resp_pkts, resp_ip_bytes, tunnel_parents, ip_proto, phase, t_rel, y_pred, y_true, hard_violation, soft_violation]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_fn_4 = false_negatives(mis_df, 4)
df_fn_4
# Out:
#      flow_id    start_time      end_time  duration         src_ip  sport  \
# 5516   f5910  9.524442e+08  9.524442e+08  0.001277  172.16.112.10   1023
#
#               dst_ip  dport proto service  ...  resp_pkts  resp_ip_bytes  \
# 5516  202.77.162.213   1018   tcp       -  ...          1             44
#
#      tunnel_parents ip_proto phase       t_rel y_pred  y_true  hard_violation  \
# 5516              -        6     4  5381.81526      0       4           False
#
#       soft_violation
# 5516           False
#
# [1 rows x 29 columns]

# %%
df_fp_4 = false_positives(mis_df, 4)
df_fp_4
# Out:
#      flow_id    start_time      end_time     duration          src_ip  sport  \
# 5180  f45437  9.524438e+08  9.524506e+08  6808.971401  197.182.91.233  13449
#
#              dst_ip  dport proto service  ...  resp_pkts  resp_ip_bytes  \
# 5180  172.16.115.20     23   tcp       -  ...       1646          75839
#
#      tunnel_parents ip_proto phase        t_rel y_pred  y_true  \
# 5180              -        6     0  4936.829975      4       0
#
#       hard_violation  soft_violation
# 5180           False           False
#
# [1 rows x 29 columns]

# %%
df_fp_4["dport"].value_counts()
# Out:
# dport
# 23    1
# Name: count, dtype: int64

# %%
df_fn_5 = false_negatives(mis_df, 5)
df_fn_5
# Out:
#       flow_id    start_time      end_time  duration          src_ip  sport  \
# 7593    f7570  9.524465e+08  9.524465e+08  0.000000     131.84.1.31  31938
# 7595    f7572  9.524465e+08  9.524465e+08  0.000000     131.84.1.31  24037
# 41890  f41865  9.524469e+08  9.524469e+08  0.025486    172.16.115.5  49591
# 41895  f41870  9.524469e+08  9.524469e+08  0.048682    172.16.115.5  49596
# 41904  f41880  9.524470e+08  9.524470e+08  0.032940  172.16.116.201  49601
# 41906  f41882  9.524470e+08  9.524470e+08  0.049896  172.16.116.201  49603
# 41907  f41883  9.524470e+08  9.524470e+08  0.076223  172.16.116.201  49604
# 41908  f41884  9.524470e+08  9.524470e+08  0.066442  172.16.116.201  49605
# 41910  f41886  9.524470e+08  9.524470e+08  0.045628  172.16.116.201  49607
# 41911  f41888  9.524470e+08  9.524470e+08  0.065035    172.16.115.5  49608
# 41912  f41889  9.524470e+08  9.524470e+08  0.045049    172.16.115.5  49609
# 41914  f41891  9.524470e+08  9.524470e+08  0.133419  172.16.116.201  49611
# 42023  f41997  9.524471e+08  9.524471e+08  0.054359    172.16.115.5  49699
# 42114  f42088  9.524473e+08  9.524473e+08  0.025293    172.16.115.5  49777
# 42115  f42089  9.524473e+08  9.524473e+08  0.048319    172.16.115.5  49778
# 42116  f42090  9.524473e+08  9.524473e+08  0.073494    172.16.115.5  49779
#
#              dst_ip  dport proto service  ...  resp_pkts  resp_ip_bytes  \
# 7593   61.56.80.155   4940   tcp       -  ...          0              0
# 7595    45.4.65.127   4942   tcp       -  ...          0              0
# 41890   131.84.1.31     80   tcp    http  ...          5           2472
# 41895   131.84.1.31     80   tcp    http  ...          9           6321
# 41904   131.84.1.31     80   tcp    http  ...          6           4445
# 41906   131.84.1.31     80   tcp    http  ...          9           6530
# 41907   131.84.1.31     80   tcp    http  ...         19          21877
# 41908   131.84.1.31     80   tcp    http  ...         13          15038
# 41910   131.84.1.31     80   tcp    http  ...          9           6321
# 41911   131.84.1.31     80   tcp    http  ...          7           3592
# 41912   131.84.1.31     80   tcp    http  ...          9           8032
# 41914   131.84.1.31     80   tcp    http  ...         30          38457
# 42023   131.84.1.31     80   tcp    http  ...          6           2035
# 42114   131.84.1.31     80   tcp    http  ...          5           2472
# 42115   131.84.1.31     80   tcp    http  ...          9           6530
# 42116   131.84.1.31     80   tcp    http  ...         19          21877
#
#       tunnel_parents ip_proto phase        t_rel y_pred  y_true  \
# 7593               -        6     5  7615.068855      0       5
# 7595               -        6     5  7615.069964      0       5
# 41890              -        6     5  8080.801671      0       5
# 41895              -        6     5  8081.114527      0       5
# 41904              -        6     5  8130.681222      0       5
# 41906              -        6     5  8130.763954      0       5
# 41907              -        6     5  8130.829802      0       5
# 41908              -        6     5  8130.929721      0       5
# 41910              -        6     5  8131.065889      0       5
# 41911              -        6     5  8143.579857      0       5
# 41912              -        6     5  8143.659630      0       5
# 41914              -        6     5  8148.355546      0       5
# 42023              -        6     5  8282.952414      0       5
# 42114              -        6     5  8423.345602      0       5
# 42115              -        6     5  8423.379288      0       5
# 42116              -        6     5  8423.435351      0       5
#
#        hard_violation  soft_violation
# 7593            False           False
# 7595            False           False
# 41890           False           False
# 41895           False           False
# 41904           False           False
# 41906           False           False
# 41907           False           False
# 41908           False           False
# 41910           False           False
# 41911           False           False
# 41912           False           False
# 41914           False           False
# 42023           False           False
# 42114           False           False
# 42115           False           False
# 42116           False           False
#
# [16 rows x 29 columns]
