# %% [markdown]
# # Analysis of Misclassifications

# %%
from pathlib import Path
import json
import pickle

import pandas as pd

# %%
# Experiment config

dataset = "aitv2"
scenario = "fox"
# scenario = "santos"

logic_file = "ait_neg"

train_mode = "scratch" 
# train_mode = "pretrained" 

fraction = 25

window_size = 10

run_id = "20260402_123738"

experiment_name = f"{logic_file}_{train_mode}_{fraction}percent_{window_size}w_{run_id}"
